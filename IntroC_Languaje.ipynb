# %% [markdown]
# ## Introduction to C

# %%
# %%file c_test.c
# #include <stdio.h>
#
# int main(void){
#     printf("Hello World from C\n");
#     printf("This is a new line at home");
#     return 0;
# }
# Out:
# Overwriting c_test.c

# %%
# %%bash
# gcc c_test.c -g -o c_test
# ./c_test

# %% [markdown]
# ## Hora de compilar!!!

# %%
# %%bash
# ./c_test
# Out:
# Hello World from C
# This is a new line
